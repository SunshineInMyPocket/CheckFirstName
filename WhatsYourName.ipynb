# %% [markdown]
# <a href="https://colab.research.google.com/github/SunshineInMyPocket/CheckFirstName/blob/main/WhatsYourName.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://pypi.org/project/Faker/
#
# You can create a python dictionary with 1000 personal names by using the Python Faker library.
# You can then convert the list to a dictionary using the `dict()` constructor:
#
# There is also a kaggle dataset for HR: https://www.kaggle.com/datasets/koluit/human-resource-data-set-the-company?resource=download

# %%
pip install Faker
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 28.8 MB/s eta 0:00:00
# ...

# %%
from faker import Faker

fake = Faker()
fake.random.seed(4321)

# %%
#Create a name dictionary
first_names = []
for i in range(1000000000):
    name = fake.first_name()
    if name not in first_names:
        first_names.append(name)

# %%
#pip install python-Levenshtein
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 41.8 MB/s eta 0:00:00
# ...

# %%
from IPython.core.interactiveshell import dis
from typing import Concatenate
import Levenshtein

name = input("Enter your name: ")

for i in first_names:
    distance = Levenshtein.distance(name, i)
    similarity = 1 - (distance / max(len(i), len(dictname)))
    if similarity >= 0.5:
      print("Name exist")
      break
# Out:
# Enter your name: mila
# Edward
# Brian
# Maria
# Cody
# Jessica
# Joseph
# Adrian
# Adam
# Gloria
# Nathan
# Taylor
# Eric
# Natalie
# Michelle
# Amy
# Thomas
# Gregory
# Rachel
# Juan
# Kimberly
# Fernando
# Melissa
# Haley
# Amber
# Jason
# Patricia
# Nicholas
# Alexis
# Becky
# Kristen
# Erica
# Hannah
# Denise
# Sharon
# Brittany
# James
# Katelyn
# Randall
# Cynthia
# Ross
# Ashley
# Rebecca
# Ann
# John
# Anthony
# Emily
# Zachary
# Deborah
# Bethany
# Mark
# Tara
# Edgar
# Jeff
# Craig
# Jimmy
# Regina
# Michael
# Matthew
# Jose
# Alan
# Nina
# Dylan
# Alvin
# Samantha
# Heather
# Jaclyn
# Daniel
# Vanessa
# Brad
# Timothy
# Richard
# Alison
# Robert
# Stephanie
# Julie
# Tammie
# Shannon
# Nancy
# Rhonda
# Angelica
# Tonya
# Heidi
# Katrina
# Lisa
# Kevin
# Justin
# Tracy
# Angela
# Johnny
# Katherine
# Jonathan
# Karen
# Victor
# Jesus
# Janet
# Donald
# Cory
# Cameron
# Sarah
# Virginia
# Morgan
# Andrew
# Peter
# Rachael
# Victoria
# Ronald
# Frank
# William
# Leslie
# ...
